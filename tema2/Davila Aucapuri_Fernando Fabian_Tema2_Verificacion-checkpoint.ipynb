# %%
import pandas as pd
import numpy as np
print("Entorno me101 funcionando correctamente")
print("pandas:", pd.__version__, "| numpy:", np.__version__)
# Out:
# Entorno me101 funcionando correctamente
# pandas: 3.0.5 | numpy: 2.4.6
